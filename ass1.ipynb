# %%
import pandas as pd
df=pd.read_csv("dataset_Facebook - dataset_Facebook.csv", sep=",");
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df['Paid'].fillna(df['Paid'].mean(),inplace=True)
df['like'].fillna(df['like'].mean(),inplace=True)
df['share'].fillna(df['share'].mean(),inplace=True)
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_40932\3710625740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Paid'].fillna(df['Paid'].mean(),inplace=True)
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_40932\3710625740.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
sub1=df[df['Type']=='Status'];
sub1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
sub2=df[df['Category']==1]
sub2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 17             138414  Photo         1          12             2         12
# 21             138414  Photo         1          12             7         10
# 22             138414   Link         1          12             7         10
# 29             138895  Video         1          12             4         11
# 34             138895  Photo         1          12             2          3
# ..                ...    ...       ...         ...           ...        ...
# 477             86909   Link         1           1             6          4
# 481             86491   Link         1           1             4          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
# 497             81370  Photo         1           1             5          2
#
# ...

# %%
sub3=df[df['Type']=='Photo']
sub3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
sub4=df.iloc[0:5,1:6]

# %%
sub4
# Out:
#      Type  Category  Post Month  Post Weekday  Post Hour
# 0   Photo         2          12             4          3
# 1  Status         2          12             3         10
# 2   Photo         3          12             3          3
# 3   Photo         2          12             2         10
# 4   Photo         2          12             2          3

# %%
sub5=df.loc[0:6]
sub5
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# ...

# %%
sub6=df[df['Lifetime Engaged Users']>1000]
sub6
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 483             86491   Photo         2           1             3          3
# 484             86491   Photo         3           1             2          7
# 486             85979   Photo         3           1             1         12
# 488             85979   Photo         3           1             7         10
# 493             85093   Photo         3           1             1          2
#
# ...

# %%
sub7=df[df['like']>80]
sub7
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
merge_p=pd.merge(sub6,sub7,on='Lifetime People who have liked your Page and engaged with your post')
merge_p
# Out:
#      Page total likes_x  Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0                139441  Status           2            12               3
# 1                139441   Photo           2            12               2
# 2                139441  Status           2            12               1
# 3                139441  Status           2            12               7
# 4                139441  Status           2            12               5
# ..                  ...     ...         ...           ...             ...
# 141               86491   Photo           3             1               3
# 142               86491   Photo           3             1               2
# 143               86491   Photo           3             1               2
# 144               85979   Photo           3             1               7
# 145               85093   Photo           3             1               1
#
#      Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# ...

# %%
concat_p=pd.concat([sub6,sub7]);
concat_p
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
sort_p=df.sort_values(by='Post Weekday',ascending=True)

# %%
sort_p
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 493             85093  Photo         3           1             1          2
# 486             85979  Photo         3           1             1         12
# 487             85979  Photo         3           1             1          2
# 20             138414  Photo         2          12             1          3
# 50             138353  Photo         2          11             1          9
# ..                ...    ...       ...         ...           ...        ...
# 462             92293  Photo         3           2             7         13
# 39             138895  Photo         1          12             7          3
# 23             138414  Photo         3          12             7          3
# 22             138414   Link         1          12             7         10
# 21             138414  Photo         1          12             7         10
#
# ...

# %%
transposed_p=df.transpose()

# %%
transposed_p
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
pivot_p=pd.pivot_table(df, index=['Category'],columns=['Type'],values=['Post Hour','Lifetime Post Impressions by people who have liked your Page'])

# %%
pivot_p
# Out:
#          Lifetime Post Impressions by people who have liked your Page  \
# Type                                                             Link
# Category
# 1                                                   11345.1
# 2                                                    8964.0
# 3                                                    9403.0
#
#                                                    Post Hour            \
# Type             Photo        Status         Video      Link     Photo
# Category
# 1         21388.508108  25141.666667  43149.857143      5.85  8.864865
# 2          8264.120879  18994.736842           NaN      6.00  6.802198
# 3         15247.126667  10666.750000           NaN      3.00  7.653333
#
#
# Type        Status     Video
# Category
# 1         9.666667  8.714286
# 2         7.131579       NaN
# 3         6.500000       NaN
